# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#load dataset
data=pd.read_csv("Student marks dataset.csv")

# %%
#first 5 rows
data.head()
# Out:
#   student  language  science  maths  history
# 0   kumar        90     56.0   34.0       34
# 1   kevin        10      NaN   32.0       67
# 2   sammy        90     23.0   12.0       32
# 3  janice        20      NaN   90.0       45
# 4   peter        30     56.0   45.0       65

# %%
#last 5 rows
data.tail()
# Out:
#   student  language  science  maths  history
# 2   sammy        90     23.0   12.0       32
# 3  janice        20      NaN   90.0       45
# 4   peter        30     56.0   45.0       65
# 5    prem        90     45.0    NaN       34
# 6  carrol        50     90.0   45.0       23

# %%
#dataset  information
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   student   7 non-null      str
#  1   language  7 non-null      int64
#  2   science   5 non-null      float64
#  3   maths     6 non-null      float64
#  4   history   7 non-null      int64
# dtypes: float64(2), int64(2), str(1)
# memory usage: 412.0 bytes

# %%
data.describe()
# Out:
#         language    science  maths    history
# count   7.000000   5.000000    6.0   7.000000
# mean   54.285714  54.000000   43.0  42.857143
# std    35.523299  24.217762   26.0  17.062909
# min    10.000000  23.000000   12.0  23.000000
# 25%    25.000000  45.000000   32.5  33.000000
# 50%    50.000000  56.000000   39.5  34.000000
# 75%    90.000000  56.000000   45.0  55.000000
# max    90.000000  90.000000   90.0  67.000000

# %%
#rows and columns count
data.shape
# Out:
# (7, 5)

# %%
#columns names
data.columns
# Out:
# Index(['student', 'language', 'science', 'maths', 'history'], dtype='str')

# %%
#empty values count
data.isnull().sum()
# Out:
# student     0
# language    0
# science     2
# maths       1
# history     0
# dtype: int64

# %%
#fillna()        (fill values in empty row)
data1=data1.fillna(0)

# %%
#empty values count in data1
data1.isnull().sum()
# Out:
# student     0
# language    0
# science     0
# maths       0
# history     0
# dtype: int64

# %%
data1.head()
# Out:
#   student  language  science  maths  history
# 0   kumar        90     56.0   34.0       34
# 2   sammy        90     23.0   12.0       32
# 4   peter        30     56.0   45.0       65
# 6  carrol        50     90.0   45.0       23

# %%
data1.shape
# Out:
# (4, 5)

# %%
#to use numpy
#average of language
np.mean(data1['language'])
# Out:
# np.float64(65.0)

# %%
np.mean(data1['science'])
# Out:
# np.float64(56.25)

# %%
np.mean(data1['maths'])
# Out:
# np.float64(34.0)

# %%
np.mean(data1['history'])
# Out:
# np.float64(38.5)

# %%
#max    (highest value)
np.max(data1['maths'])
# Out:
# np.float64(45.0)

# %%
#min        (lowest value)
np.min(data1['maths'])
# Out:
# np.float64(12.0)

# %%
#sum   (total language  marks)
np.sum(data1['maths'])
# Out:
# np.float64(136.0)

# %%
#median
np.median(data1['maths'])
# Out:
# np.float64(39.5)

# %%
#sort
np.sort(data1['maths'])
# Out:
# array([12., 34., 45., 45.])

# %%
#unique
np.unique(data1['maths'])
# Out:
# array([12., 34., 45.])
