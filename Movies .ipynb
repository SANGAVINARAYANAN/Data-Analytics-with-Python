# %%
import pandas as pd

# %%
data=pd.read_csv("movies.csv")

# %%
data.head()
# Out:
#    srno                 movie  year  rating    time
# 0     1  The Nightmare Before  1993     3.9  4568.0
# 1     2             The Mummy  1932     3.5  4388.0
# 2     3  Orphans of the Storm  1921     3.2  9062.0
# 3     4  The Object of Beauty  1991     2.8  6150.0
# 4     5            Night Tide  1963     2.8  5126.0

# %%
data.tail()
# Out:
#         srno                                              movie  year  rating  \
# 49585  49586                                  Winter Wonderland  2013     2.8
# 49586  49587                Top Gear: Series 19: Africa Special  2013     NaN
# 49587  49588  Fireplace For Your Home: Crackling Fireplace w...  2010     NaN
# 49588  49589                                    Kate Plus Ei8ht  2010     2.7
# 49589  49590                          Kate Plus Ei8ht: Season 1  2010     2.7
#
#          time
# 49585  1812.0
# 49586  6822.0
# 49587  3610.0
# 49588     NaN
# 49589     NaN

# %%
data.describe()
# Out:
#                srno          year        rating          time
# count  49590.000000  49590.000000  10814.000000  45836.000000
# mean   24795.500000   2002.303428      3.451248   2628.445436
# std    14315.544261     12.534555      0.495601   1604.646265
# min        1.000000   1913.000000      1.400000     52.000000
# 25%    12398.250000   1999.000000      3.100000   1356.000000
# 50%    24795.500000   2007.000000      3.500000   2563.000000
# 75%    37192.750000   2010.000000      3.800000   2877.000000
# max    49590.000000   2014.000000      4.500000  28813.000000

# %%
data.shape
# Out:
# (49590, 5)

# %%
data.columns
# Out:
# Index(['srno', 'movie', 'year', 'rating', 'time'], dtype='str')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49590 entries, 0 to 49589
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   srno    49590 non-null  int64
#  1   movie   49590 non-null  str
#  2   year    49590 non-null  int64
#  3   rating  10814 non-null  float64
#  4   time    45836 non-null  float64
# dtypes: float64(2), int64(2), str(1)
# memory usage: 1.9 MB

# %%
#total movies
len(data)
# Out:
# 49590

# %%
#missing values count
data.isnull().sum()
# Out:
# srno          0
# movie         0
# year          0
# rating    38776
# time       3754
# dtype: int64

# %%
#duplicates values count
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
#remove duplicates
data.drop_duplicates()
# Out:
#         srno                                              movie  year  rating  \
# 0          1                               The Nightmare Before  1993     3.9
# 1          2                                          The Mummy  1932     3.5
# 2          3                               Orphans of the Storm  1921     3.2
# 3          4                               The Object of Beauty  1991     2.8
# 4          5                                         Night Tide  1963     2.8
# ...      ...                                                ...   ...     ...
# 49585  49586                                  Winter Wonderland  2013     2.8
# 49586  49587                Top Gear: Series 19: Africa Special  2013     NaN
# 49587  49588  Fireplace For Your Home: Crackling Fireplace w...  2010     NaN
# 49588  49589                                    Kate Plus Ei8ht  2010     2.7
# 49589  49590                          Kate Plus Ei8ht: Season 1  2010     2.7
#
#          time
# 0      4568.0
# ...

# %%
#filtering by rating
data1=data[data["rating"]>4]
data1
# Out:
#         srno                                              movie  year  rating  \
# 138      139                                       Pulp Fiction  1994     4.1
# 287      288                                  Life Is Beautiful  1997     4.2
# 302      303                             Mulan: Special Edition  1998     4.2
# 464      465                                       Forrest Gump  1994     4.3
# 490      491                                         Braveheart  1995     4.2
# ...      ...                                                ...   ...     ...
# 49548  49549                           Life With Boys: Season 1  2011     4.1
# 49553  49554                                          Max Steel  2013     4.1
# 49555  49556                       Lilyhammer: Season 1 (Recap)  2013     4.2
# 49570  49571                           The Short Game (Trailer)  2013     4.1
# 49578  49579  Transformers Prime Beast Hunters: Predacons Ri...  2013     4.2
#
#           time
# 138     9265.0
# ...

# %%
data1.shape
# Out:
# (897, 5)

# %%
#filtering by year
data2=data[data["year"]==2000]
data2
# Out:
#         srno                                              movie  year  rating  \
# 409      410                                            Believe  2000     3.3
# 416      417                         The Prophecy 3: The Ascent  2000     3.4
# 430      431                                           Scream 3  2000     3.2
# 431      432                                   The Tigger Movie  2000     3.5
# 432      433                                         Holy Smoke  2000     3.0
# ...      ...                                                ...   ...     ...
# 46868  46869  Digimon Adventure: Season 2: Gigantic Ultimate...  2000     NaN
# 46870  46871  Digimon Adventure: Season 2: Steel Angel  Shak...  2000     NaN
# 46874  46875  Digimon Adventure: Season 2: Assault! BlackWar...  2000     NaN
# 46876  46877  Digimon Adventure: Season 2: Defend the Holy P...  2000     NaN
# 46877  46878  Digimon Adventure: Season 2: Today Miyako Is i...  2000     NaN
#
#          time
# 409    5767.0
# ...

# %%
data2.shape
# Out:
# (902, 5)

# %%
#sorting highest_rating
data.sort_values("rating",ascending=False)
# Out:
#         srno                                              movie  year  rating  \
# 14954  14955                             Breaking Bad: Season 4  2011     4.5
# 14956  14957                                 Sherlock: Series 1  2010     4.5
# 37896  37897                         The Walking Dead: Season 3  2012     4.5
# 30425  30426                                       The Avengers  2012     4.5
# 26483  26484                                           Sherlock  2010     4.5
# ...      ...                                                ...   ...     ...
# 49563  49564    My Hope America with Billy Graham: Lose to Gain  2013     NaN
# 49576  49577  Barbie: Life in the Dreamhouse: Barbie Life in...  2013     NaN
# 49577  49578  Barbie: Life in the Dreamhouse: Barbie Life in...  2013     NaN
# 49586  49587                Top Gear: Series 19: Africa Special  2013     NaN
# 49587  49588  Fireplace For Your Home: Crackling Fireplace w...  2010     NaN
#
#          time
# 14954     NaN
# ...

# %%
#sorting lowest_rating
data.sort_values("rating")
# Out:
#         srno                                              movie  year  rating  \
# 40934  40935                                             Lagegi  2007     1.4
# 40826  40827                                             Lagegi  2007     1.4
# 42115  42116                                Sun Yaar Chill Maar  2007     1.4
# 42160  42161                                Sun Yaar Chill Maar  2007     1.4
# 41396  41397                           Meri Toh Lag Gayi Naukri  2011     1.5
# ...      ...                                                ...   ...     ...
# 49563  49564    My Hope America with Billy Graham: Lose to Gain  2013     NaN
# 49576  49577  Barbie: Life in the Dreamhouse: Barbie Life in...  2013     NaN
# 49577  49578  Barbie: Life in the Dreamhouse: Barbie Life in...  2013     NaN
# 49586  49587                Top Gear: Series 19: Africa Special  2013     NaN
# 49587  49588  Fireplace For Your Home: Crackling Fireplace w...  2010     NaN
#
#          time
# 40934     NaN
# ...
